# %% [markdown]
# <a href="https://colab.research.google.com/github/carloscarrasco44/ProyectoUnidad2/blob/main/Desnormalizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/carloscarrasco44/ProyectoUnidad2
# Out:
# Cloning into 'ProyectoUnidad2'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 58 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 6.82 MiB | 2.92 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
import pandas as pd

# Cargar archivos
try:
    cities = pd.read_csv("./ProyectoUnidad2/Datos/data/Cities.csv")
except FileNotFoundError:
    print("Error: 'Cities.csv' not found. Please ensure the file is in the correct directory.")
    cities = None # Assign None to avoid NameError later if not found

try:
    game_cities = pd.read_csv("./ProyectoUnidad2/Datos/data/MGameCities.csv")
except FileNotFoundError:
    print("Error: 'MGameCities.csv' not found. Please ensure the file is in the correct directory.")
    game_cities = None # Assign None to avoid NameError later if not found

# Mostrar tablas
if cities is not None:
    print(cities.head())
if game_cities is not None:
    print(game_cities.head())
# Out:
#    CityID         City State
# 0    4001      Abilene    TX
# 1    4002        Akron    OH
# 2    4003       Albany    NY
# 3    4004  Albuquerque    NM
# 4    4005    Allentown    PA
#    Season  DayNum  WTeamID  LTeamID   CRType  CityID
# 0    2010       7     1143     1293  Regular    4027
# 1    2010       7     1314     1198  Regular    4061
# 2    2010       7     1326     1108  Regular    4080
# 3    2010       7     1393     1107  Regular    4340
# 4    2010       9     1143     1178  Regular    4027

# %%
# Unir tablas (DESNORMALIZACIÓN)

tabla_desnormalizada = pd.merge(
    game_cities,
    cities,
    on='CityID',
    how='left'
)

# Mostrar resultado
print(tabla_desnormalizada.head())
# Out:
#    Season  DayNum  WTeamID  LTeamID   CRType  CityID         City State
# 0    2010       7     1143     1293  Regular    4027     Berkeley    CA
# 1    2010       7     1314     1198  Regular    4061  Chapel Hill    NC
# 2    2010       7     1326     1108  Regular    4080     Columbus    OH
# 3    2010       7     1393     1107  Regular    4340     Syracuse    NY
# 4    2010       9     1143     1178  Regular    4027     Berkeley    CA

# %%
tabla_desnormalizada.to_excel('tabla_desnormalizada.xlsx', index=False)
